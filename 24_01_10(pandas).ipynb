# %% [markdown]
# <a href="https://colab.research.google.com/github/Cheunji/aipython/blob/main/24_01_10(pandas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.DataFrame([['Kim',27,92],
                   ['Lee',33,98],
                   ['Park',19,87]])
df
# Out:
#       0   1   2
# 0   Kim  27  92
# 1   Lee  33  98
# 2  Park  19  87

# %%
df = pd.DataFrame({'name':['Kim','Lee','Park'],
                   'age':[27,33,19],
                   'score':[92,98,87]})

df
# Out:
#    name  age  score
# 0   Kim   27     92
# 1   Lee   33     98
# 2  Park   19     87

# %% [markdown]
# **외부 데이터 불러오기**

# %%
# CSV파일

df1 = pd.read_csv('data.csv', encoding='UTF-8')
df1
# Out:
#    name   age   score
# 0   Kim    27      92
# 1   Lee    33      98
# 2  Park    19      87

# %%
# 웹에서 csv파일 불러오기

url = "https://raw.githubusercontent.com/Datamanim/pandas/main/lol.csv"
df2 = pd.read_csv(url, delimiter='\t')

df2
# Out:
#            gameId   creationTime  gameDuration  seasonId  winner  firstBlood  \
# 0      3326086514  1504279457970          1949         9       1           2
# 1      3229566029  1497848803862          1851         9       1           1
# 2      3327363504  1504360103310          1493         9       1           2
# 3      3326856598  1504348503996          1758         9       1           1
# 4      3330080762  1504554410899          2094         9       1           2
# ...           ...            ...           ...       ...     ...         ...
# 51485  3308904636  1503076540231          1944         9       2           1
# 51486  3215685759  1496957179355          3304         9       2           1
# 51487  3322765040  1504029863961          2156         9       2           2
# 51488  3256675373  1499562036246          1475         9       2           2
# 51489  3317333020  1503612754059          1445         9       1           1
#
# ...

# %%
# 엑셀 파일

df = pd.read_excel('data.xlsx')
# df.head(3)
# df.tail(3)
df.info() # 데이터의 기본 정보 # object(대부분 문자열)
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   반       10 non-null     object
#  1   이름      10 non-null     object
#  2   성별      10 non-null     object
#  3   국어      7 non-null      float64
#  4   수학      7 non-null      float64
#  5   응시여부    8 non-null      object
#  6   확인여부    7 non-null      object
# dtypes: float64(2), object(5)
# memory usage: 688.0+ bytes
#     반   이름 성별    국어     수학 응시여부 확인여부
# 0  A반  구이서  남  90.0   89.0   응시   확인
# 1  B반  김이정  여  78.0   45.0   응시   확인
# 2  A반  오지수  남   NaN    NaN   응시   확인
# 3  B반  김선후  남  33.0   44.0   응시  NaN
# 4  A반  하진희  여   0.0   85.0   응시  NaN
# 5  A반  강현진  남   NaN    NaN  NaN  NaN
# 6  B반  김진솔  남  90.0   89.0   응시   확인
# 7  B반  박서준  여  78.0   45.0   응시   확인
# 8  A반  김성희  남   NaN    NaN  NaN   확인
# 9  B반  이지서  여  86.0  100.0   응시   확인

# %% [markdown]
# **데이터 보기**

# %%
# df.head(3)
# df.tail(3)
# df.info

# 특정 칼럼의 데이터 보기
df['이름'] # df.이름
df[['이름','성별']]
# Out:
#     이름 성별
# 0  구이서  남
# 1  김이정  여
# 2  오지수  남
# 3  김선후  남
# 4  하진희  여
# 5  강현진  남
# 6  김진솔  남
# 7  박서준  여
# 8  김성희  남
# 9  이지서  여

# %%
# 행 범위 지정

df[0:3]
df['이름'][0:3]
# Out:
# 0    구이서
# 1    김이정
# 2    오지수
# Name: 이름, dtype: object

# %%
df.loc[2]
# Out:
# 반        A반
# 이름      오지수
# 성별        남
# 국어      NaN
# 수학      NaN
# 응시여부     응시
# 확인여부     확인
# Name: 2, dtype: object

# %%
df.loc[0:3,['이름']]
# Out:
#     이름
# 0  구이서
# 1  김이정
# 2  오지수
# 3  김선후

# %%
df.iloc[1,2]
# Out:
# '여'

# %%
df.iloc[0:3,0:2]
# Out:
#     반   이름
# 0  A반  구이서
# 1  B반  김이정
# 2  A반  오지수

# %%
df['국어']>=80
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# 9     True
# Name: 국어, dtype: bool

# %%
df[df['국어']>=80]
# Out:
#     반   이름 성별    국어     수학 응시여부 확인여부
# 0  A반  구이서  남  90.0   89.0   응시   확인
# 6  B반  김진솔  남  90.0   89.0   응시   확인
# 9  B반  이지서  여  86.0  100.0   응시   확인

# %%
df[(df['국어']>=80)&(df['수학']>=90)]
# Out:
#     반   이름 성별    국어     수학 응시여부 확인여부
# 9  B반  이지서  여  86.0  100.0   응시   확인

# %%
df[(df['국어']>=80) | (df['수학']>=90)]
# Out:
#     반   이름 성별    국어     수학 응시여부 확인여부
# 0  A반  구이서  남  90.0   89.0   응시   확인
# 6  B반  김진솔  남  90.0   89.0   응시   확인
# 9  B반  이지서  여  86.0  100.0   응시   확인

# %% [markdown]
# **데이터 정렬**

# %%
df.sort_values(by=['이름']) # 오름차순(ascending=True)
# Out:
#     반   이름 성별    국어     수학 응시여부 확인여부
# 5  A반  강현진  남   NaN    NaN  NaN  NaN
# 0  A반  구이서  남  90.0   89.0   응시   확인
# 3  B반  김선후  남  33.0   44.0   응시  NaN
# 8  A반  김성희  남   NaN    NaN  NaN   확인
# 1  B반  김이정  여  78.0   45.0   응시   확인
# 6  B반  김진솔  남  90.0   89.0   응시   확인
# 7  B반  박서준  여  78.0   45.0   응시   확인
# 2  A반  오지수  남   NaN    NaN   응시   확인
# 9  B반  이지서  여  86.0  100.0   응시   확인
# 4  A반  하진희  여   0.0   85.0   응시  NaN

# %%
sorted_df = df.sort_values(by=['국어'], ascending=False)

# %% [markdown]
# **판다스 데이터프레임 활용하기**

# %%
df.describe()
# Out:
#              국어          수학
# count   7.00000    7.000000
# mean   65.00000   71.000000
# std    34.82815   25.053277
# min     0.00000   44.000000
# 25%    55.50000   45.000000
# 50%    78.00000   85.000000
# 75%    88.00000   89.000000
# max    90.00000  100.000000

# %%
# 칼럼값별 데이터 개수 보기
# 범주형 데이터( : 반, 성별, 날씨 등)의 분포(빈도) 이해 - value_counts()

df['반'].value_counts()
# Out:
# A반    5
# B반    5
# Name: 반, dtype: int64

# %%
# 개별 칼럼의 통계값

# df['국어'].sum()
df['국어'].mean()
# Out:
# 65.0

# %%
# 그룹별 통계값

df.groupby('반').sum()
# Out:
# <ipython-input-35-8718f44ae47b>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('반').sum()
#        국어     수학
# 반
# A반   90.0  174.0
# B반  365.0  323.0

# %% [markdown]
# **결측치 처리**

# %% [markdown]
# **데이터프레임의 변경**

# %%
df['총점'] = df['국어'] + df['수학']
df
# Out:
#     반   이름 성별    국어     수학 응시여부 확인여부     총점
# 0  A반  구이서  남  90.0   89.0   응시   확인  179.0
# 1  B반  김이정  여  78.0   45.0   응시   확인  123.0
# 2  A반  오지수  남   NaN    NaN   응시   확인    NaN
# 3  B반  김선후  남  33.0   44.0   응시  NaN   77.0
# 4  A반  하진희  여   0.0   85.0   응시  NaN   85.0
# 5  A반  강현진  남   NaN    NaN  NaN  NaN    NaN
# 6  B반  김진솔  남  90.0   89.0   응시   확인  179.0
# 7  B반  박서준  여  78.0   45.0   응시   확인  123.0
# 8  A반  김성희  남   NaN    NaN  NaN   확인    NaN
# 9  B반  이지서  여  86.0  100.0   응시   확인  186.0

# %%
df.drop('확인여부',axis=1)
# Out:
#     반   이름 성별    국어     수학 응시여부     총점
# 0  A반  구이서  남  90.0   89.0   응시  179.0
# 1  B반  김이정  여  78.0   45.0   응시  123.0
# 2  A반  오지수  남   NaN    NaN   응시    NaN
# 3  B반  김선후  남  33.0   44.0   응시   77.0
# 4  A반  하진희  여   0.0   85.0   응시   85.0
# 5  A반  강현진  남   NaN    NaN  NaN    NaN
# 6  B반  김진솔  남  90.0   89.0   응시  179.0
# 7  B반  박서준  여  78.0   45.0   응시  123.0
# 8  A반  김성희  남   NaN    NaN  NaN    NaN
# 9  B반  이지서  여  86.0  100.0   응시  186.0

# %% [markdown]
# **MISSION**

# %%
# 1. 데이터프레임을 생성한 후 데이터프레임의 정보를 출력하시오.

BoxOffice_df = pd.read_excel("BoxOffice.xlsx")
BoxOffice_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   순위      200 non-null    int64
#  1   영화명     200 non-null    object
#  2   개봉일     200 non-null    datetime64[ns]
#  3   매출액     200 non-null    int64
#  4   관객수     200 non-null    int64
#  5   스크린수    200 non-null    int64
#  6   상영횟수    200 non-null    int64
#  7   대표국적    200 non-null    object
#  8   국적      200 non-null    object
#  9   배급사     200 non-null    object
# dtypes: datetime64[ns](1), int64(5), object(4)
# memory usage: 15.8+ KB

# %%
# 2. 대표국적별 영화 편수를 집계하시오.

BoxOffice_df.value_counts('대표국적')
# BoxOffice_df['대표국적'].value_counts -> (X)
# Out:
# 대표국적
# 한국    116
# 미국     82
# 영국      1
# 일본      1
# dtype: int64

# %%
# 3. 대표국적이 '영국'인 데이터를 출력하시오.
BoxOffice_df[BoxOffice_df['대표국적']=='영국']
# Out:
#       순위     영화명        개봉일          매출액      관객수  스크린수   상영횟수 대표국적  국적  \
# 194  195  어바웃 타임 2013-12-05  25312684300  3449451   568  67267   영국  영국
#
#                      배급사
# 194  유니버설픽쳐스인터내셔널 코리아(유)

# %%
# 4. 대표국적별 최상위 순위를 출력하시오.

BoxOffice_df.groupby('대표국적').min()
# Out:
# <ipython-input-54-1ecda3a256e0>:3: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   BoxOffice_df.groupby('대표국적').min()
#        순위        개봉일          매출액      관객수  스크린수   상영횟수  국적  \
# 대표국적
# 미국      5 2005-12-01  21476688172  3379762   319  38456  미국
# 영국    195 2013-12-05  25312684300  3449451   568  67267  영국
# 일본    172 2017-01-04  30628194346  3793790   947  88917  일본
# 한국      1 2005-01-27  22209675300  3389125   238  47155  한국
#
#                          배급사
# 대표국적
# 미국    (주)디스테이션,워너브러더스 코리아(주)
# 영국       유니버설픽쳐스인터내셔널 코리아(유)
# 일본             메가박스중앙(주)플러스엠
# 한국       (주)넥스트엔터테인먼트월드(NEW)
